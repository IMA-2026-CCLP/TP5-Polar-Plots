# %% [markdown]
# ## PARTE 2

# %% [markdown]
# Ya en la parte 1 se filtro y se alineo la referencia, se guardo el tensor y aca simplemente se lo levanta para hacer mas sencillo el procesamiento de las tomas. Se puede comparar el resultado con el tensor sin filtrar ni alinear para ver la mejora que se obtiene.

# %%
# %load_ext autoreload
# %autoreload 2
from mic_array.patron import MicArray
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ma_processed = MicArray.from_tensor("data/tensores/forte_hpf_aligned.npy")
ma_processed.downsampling_graph = 100 
ma_processed.smoothing_ms = 20
# Out:
# MicArray loaded — shape: (19, 20, 286650)  sr: 44100 Hz

# %%
ma_processed.plot_takes(azimuth=20, envelope=True)
